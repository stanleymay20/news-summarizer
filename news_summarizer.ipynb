# %%
# !pip install flask requests beautifulsoup4 nltk scikit-learn transformers tensorflow rouge-score python-dotenv schedule sqlalchemy
# Out:
# Requirement already satisfied: flask in c:\users\stanley\news-summarizer\myenv\lib\site-packages (3.0.3)
# Requirement already satisfied: requests in c:\users\stanley\news-summarizer\myenv\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (4.12.3)
# Requirement already satisfied: nltk in c:\users\stanley\news-summarizer\myenv\lib\site-packages (3.8.1)
# Requirement already satisfied: scikit-learn in c:\users\stanley\news-summarizer\myenv\lib\site-packages (1.5.1)
# Requirement already satisfied: transformers in c:\users\stanley\news-summarizer\myenv\lib\site-packages (4.43.2)
# Requirement already satisfied: tensorflow in c:\users\stanley\news-summarizer\myenv\lib\site-packages (2.17.0)
# Requirement already satisfied: rouge-score in c:\users\stanley\news-summarizer\myenv\lib\site-packages (0.1.2)
# Requirement already satisfied: python-dotenv in c:\users\stanley\news-summarizer\myenv\lib\site-packages (1.0.1)
# Requirement already satisfied: schedule in c:\users\stanley\news-summarizer\myenv\lib\site-packages (1.2.2)
# Requirement already satisfied: sqlalchemy in c:\users\stanley\news-summarizer\myenv\lib\site-packages (2.0.31)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from flask) (1.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: joblib in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: filelock in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from transformers) (0.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.4)
# Requirement already satisfied: setuptools in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (71.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.65.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from sqlalchemy) (3.0.3)
# Requirement already satisfied: colorama in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\stanley\news-summarizer\myenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)

# %%
# Import necessary libraries
import os
import requests
from bs4 import BeautifulSoup
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from transformers import pipeline, TFAutoModelForSeq2SeqLM, AutoTokenizer
from rouge_score import rouge_scorer
from dotenv import load_dotenv
import schedule
import time
from datetime import datetime
from flask import Flask, jsonify

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Load environment variables
load_dotenv()

NEWS_API_KEY = os.getenv('NEWS_API_KEY')
WORDPRESS_URL = os.getenv('WORDPRESS_URL')
WORDPRESS_USERNAME = os.getenv('WORDPRESS_USERNAME')
WORDPRESS_PASSWORD = os.getenv('WORDPRESS_PASSWORD')

# Fetch articles from NewsAPI
def fetch_articles_from_newsapi(query, api_key):
    url = f'https://newsapi.org/v2/everything?q={query}&apiKey={api_key}'
    response = requests.get(url)
    articles = response.json().get('articles', [])
    return articles

# Fetch articles from Reuters
def fetch_articles_from_reuters():
    url = 'https://www.reuters.com/news/archive/worldNews'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    articles = []
    for item in soup.select('.story-content a'):
        article_url = 'https://www.reuters.com' + item['href']
        article_response = requests.get(article_url)
        article_soup = BeautifulSoup(article_response.content, 'html.parser')
        title = article_soup.find('h1').get_text()
        content = ' '.join(p.get_text() for p in article_soup.find_all('p'))
        articles.append({'title': title, 'content': content})
    return articles

# Preprocess text data
def preprocess_text(text):
    sentences = nltk.sent_tokenize(text)
    words = [nltk.word_tokenize(sentence) for sentence in sentences]
    words = [word.lower() for sentence in words for word in sentence if word.isalpha()]
    return ' '.join(words)

# Extractive summarization
def extractive_summary(text, num_sentences=5):
    sentences = nltk.sent_tokenize(text)
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(sentences)
    kmeans = KMeans(n_clusters=num_sentences)
    kmeans.fit(X)
    selected_sentences = [sentences[i] for i in kmeans.cluster_centers_.argsort()[:, -1]]
    return ' '.join(selected_sentences)

# Abstractive summarization
def abstractive_summary(text, max_length=130, min_length=30):
    model_name = "t5-small"
    model = TFAutoModelForSeq2SeqLM.from_pretrained(model_name)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    summarizer = pipeline('summarization', model=model, tokenizer=tokenizer, framework='tf')
    summary = summarizer(text, max_length=max_length, min_length=min_length, do_sample=False)
    return summary[0]['summary_text']

# Evaluate summary using ROUGE
def evaluate_summary(reference, summary):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference, summary)
    return scores

# Post summary to WordPress
def post_to_wordpress(title, content, url, username, password):
    data = {
        'title': title,
        'content': content,
        'status': 'publish'
    }
    response = requests.post(url, json=data, auth=(username, password))
    return response.json()

# Fetch, summarize, and post articles
def post_summaries():
    newsapi_articles = fetch_articles_from_newsapi('latest news', NEWS_API_KEY)
    reuters_articles = fetch_articles_from_reuters()

    all_articles = newsapi_articles + reuters_articles

    for article in all_articles:
        content = article.get('content') or article.get('description', '')
        preprocessed_text = preprocess_text(content)
        extractive = extractive_summary(preprocessed_text)
        abstractive = abstractive_summary(preprocessed_text)

        summary = f"Extractive Summary: {extractive}\n\nAbstractive Summary: {abstractive}"

        post_to_wordpress(article.get('title', 'No Title'), summary, WORDPRESS_URL, WORDPRESS_USERNAME, WORDPRESS_PASSWORD)

# Flask app to trigger summarization
app = Flask(__name__)

@app.route('/summarize', methods=['POST'])
def summarize():
    response = post_summaries()
    return jsonify({"status": "success", "response": response}), 200

# Schedule the job
schedule.every().day.at("08:00").do(post_summaries)

if __name__ == '__main__':
    app.run(debug=True)

# Keep the script running to check the schedule
while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 8
#       6 from sklearn.feature_extraction.text import TfidfVectorizer
#       7 from sklearn.cluster import KMeans
# ----> 8 from transformers import pipeline, TFAutoModelForSeq2SeqLM, AutoTokenizer
#       9 from rouge_score import rouge_scorer
#      10 from dotenv import load_dotenv
#
# ModuleNotFoundError: No module named 'transformers'

# %%
try:
    from transformers import pipeline, TFAutoModelForSeq2SeqLM, AutoTokenizer
    print("Transformers library imported successfully.")
except ModuleNotFoundError as e:
    print("Error importing transformers:", e)
# Out:
# Error importing transformers: No module named 'transformers'
